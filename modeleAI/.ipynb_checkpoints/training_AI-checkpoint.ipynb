# %%
import gdown
import tempfile
import os
import cv2
import zipfile
import numpy as np
from tqdm import tqdm
import time

# %%
url = "https://drive.google.com/uc?id=1TMEd1MA0Vy4PJycfBjx2a_EG0i9jpOzN"

# %%
net = cv2.dnn.readNet("./training data/yolov3-tiny.weights", "./training data/yolov3-tiny.cfg")

ln = net.getLayerNames()
output_layers = [ln[i-1] for i in net.getUnconnectedOutLayers()]

# %%
if net is None:
    net = cv2.dnn.readNet("./training data/yolov3-tiny.weights", "./training data/yolov3-tiny.cfg")
print(f"Yolo weights path: {yolov3_weights_path}")
print(f"Yolo cfg path: {yolov3_cfg_path}")

try:
    with open(yolov3_cfg_path, "rb") as f:
        config_data = f.read()
    print(config_data[:50])  # Affiche les premières lignes du fichier pour vérifier son contenu
except Exception as e:
    print(f"Erreur lors de la lecture du fichier de configuration YOLO : {str(e)}")

net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
# Out:
# Yolo weights path: /Users/davidr/Epitech/DavidRfo/Hackathon/modeleAI/training data/yolov3-tiny.weights
# Yolo cfg path: /Users/davidr/Epitech/DavidRfo/Hackathon/modeleAI/training data/yolov3-tiny.cfg
# b'[net]\n# Testing\n# batch=1\n# subdivisions=1\n# Train'

# %%
classes = []
with open("./training data/coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# Créez une liste des classes de véhicules
vehicle_classes = [cls for cls in classes if cls.startswith(("car", "truck"))]

confidence_threshold = 0.5

# %%
# Chemin absolu vers le dossier parent
parent_directory = "/Users/davidr/Epitech/DavidRfo/Hackathon/modeleAI/"

# Chemin absolu vers le dossier training data
training_data_directory = os.path.join(parent_directory, "training data")

# Chemin absolu vers les fichiers YOLO
yolov3_weights_path = os.path.join(training_data_directory, "yolov3-tiny.weights")
yolov3_cfg_path = os.path.join(training_data_directory, "yolov3-tiny.cfg")

print(f"Yolo weights path: {yolov3_weights_path}")
print(f"Yolo cfg path: {yolov3_cfg_path}")

if not os.path.exists(yolov3_weights_path) or not os.path.exists(yolov3_cfg_path):
    raise FileNotFoundError("Le fichier YOLO poids ou configuration manque.")
# Out:
# Yolo weights path: /Users/davidr/Epitech/DavidRfo/Hackathon/modeleAI/training data/yolov3-tiny.weights
# Yolo cfg path: /Users/davidr/Epitech/DavidRfo/Hackathon/modeleAI/training data/yolov3-tiny.cfg

# %%
import stat

os.chmod(yolov3_weights_path, stat.S_IRUSR | stat.S_IWUSR | stat.S_IRGRP | stat.S_IROTH)
os.chmod(yolov3_cfg_path, stat.S_IRUSR | stat.S_IWUSR | stat.S_IRGRP | stat.S_IROTH)

# %%
with open(f"{yolov3_cfg_path}", "rb") as f:
    config_data = f.read()

print(config_data[:50])  # Affiche les premières lignes du fichier pour vérifier son contenu

# Liste des classes de véhicules
vehicle_classes = ["car", "truck"]

# Configuration YOLO
conf_threshold = 0.5
input_size = (416, 416)
# Out:
# b'[net]\n# Testing\n# batch=1\n# subdivisions=1\n# Train'

# %%
def reduce_resolution(image):
    height, width = image.shape[:2]
    ratio = min(640 / height, 640 / width)
    new_height = int(height * ratio)
    new_width = int(width * ratio)
    
    # Assurez-vous que la nouvelle taille est au moins 416x416
    new_height = max(new_height, 416)
    new_width = max(new_width, 416)
    
    # Normalise l'image avant la réduction de résolution
    normalized_image = image.astype(np.float32) / 255.0
    
    # Appliquez la réduction de résolution sur l'image normalisée
    resized_image = cv2.resize(normalized_image, (int(new_width), int(new_height)))
    
    # Dénormalisez l'image après la réduction de résolution
    resized_image = (resized_image * 255).astype(np.uint8)
    
    return resized_image

# %%
def blob_from_image(image):
    mean = np.array([104., 117., 123.])  # Moyenne de BGR
    return cv2.dnn.blobFromImage(image, 1/255, (416, 416), mean, swapRB=True, crop=False)

# %%
def process_single_frame(frame_buffer):
    #preprocessed_frame = preprocess_image(frame_buffer[0])
    vehicle_boxes = detect_and_segment_vehicles(frame_buffer[0])#preprocessed_frame)
    return vehicle_boxes

# %%
def preprocess_image(image):
    # Nettoie les images (filtrage, correction de luminosité)
    lab_image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    
    # Corrige de luminosité
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    lab_image[:,:,0] = clahe.apply(lab_image[:,:,0])
    
    # Retourne à l'espace BGR sans modification
    return image  # Retourne l'image originale en BGR

# %%
def detect_and_segment_vehicles(frame):
    # Utilise YOLO pour détecter les véhicules dans chaque frame
    global net
    if net is None:
        net = cv2.dnn.readNet("./training data/yolov3-tiny.weights", "./training data/yolov3-tiny.cfg")
    
    # Préparation de l'image pour YOLO
    blob = cv2.dnn.blobFromImage(frame, 1/255, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)
    
    outputs = net.forward(net.getUnconnectedOutLayersNames())
    
    # Détecte et segmente les véhicules
    vehicle_boxes = []
    for output in outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            
            # Utilisez uniquement les classes qui commencent par "car" ou "truck"
            if confidence > 0.2 and (class_id == 2 or class_id == 7):  # Classe 2 est utilisée pour les véhicules,
                                                                    # classe 7 pour les camions
                x, y, w, h = detection[0:4] * np.array([frame.shape[1], frame.shape[0], frame.shape[1], frame.shape[0]])
                vehicle_boxes.append((x, y, x+w, y+h))
                
                vehicle_boxes[-1] += (confidence, class_id)
    
    return vehicle_boxes if vehicle_boxes else []

# %%
def draw_bounding_boxes(frame, vehicle_boxes):
    detected_frame = frame.copy()
    for box in vehicle_boxes:
        x, y, w, h = box
        color = tuple(np.random.randint(0, 256, 3).tolist())
        cv2.rectangle(detected_frame, (x, y), (x+w, y+h), color, 2)
    return detected_frame

# %%
def display_results(results):
    for result in results:
        cv2.imshow("Frame with detections", result["detected_image"])
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

def show_results(results):
    fig, ax = plt.subplots(figsize=(20, 10))
    for result in results:
        ax.imshow(result["detected_image"])
        ax.set_title(f'Frame {result["frame_number"]}, Véhicules détectés: {len(result["vehicle_boxes"])}')
        plt.axis('off')
        plt.show(block=False)
        plt.pause(0.5)
        plt.close()

# %%
def main():
    
    segment_duration = 20  # Durée de chaque segment en secondes
    
    try:
        # Télécharge le fichier dans un dossier temporaire
        temp_dir = tempfile.TemporaryDirectory()
        output_path = os.path.join(temp_dir.name, "2-Jeu_Test_J2-10h30_P5 11.17.01.mp4.zip")

        print("Téléchargement...")
        gdown.download(url, output=output_path)
        print(f"Fichier téléchargé dans : {output_path}")

        # Extrait tous les fichiers MP4 du ZIP
        mp4_files = []
        with zipfile.ZipFile(output_path, 'r') as zip_ref:
            mp4_files = [member.filename for member in zip_ref.infolist() if member.filename.endswith('.mp4')]

        if len(mp4_files) == 0:
            raise ValueError("Aucun fichier MP4 trouvé dans le ZIP.")
        elif len(mp4_files) > 1:
            print(f"Plusieurs fichiers MP4 trouvés : {', '.join(mp4_files)}")
            # Choisit le premier fichier MP4 pour l'extraction
            mp4_filename = mp4_files[0]
        else:
            mp4_filename = mp4_files[0]

        extracted_mp4_path = os.path.join(temp_dir.name, mp4_filename)

        # Extrait le fichier MP4 sélectionné en excluant les fichiers cachés Mac OS
        with zipfile.ZipFile(output_path, 'r') as zip_ref:
            mp4_file_info = next(filter(lambda m: m.filename == mp4_filename, zip_ref.infolist()))
            zip_ref.extract(member=zip_ref.infolist()[zip_ref.infolist().index(next(filter(lambda m: m.filename == mp4_filename, zip_ref.infolist())))], path=temp_dir.name, pwd=b"password")       
            print(f"Fichier MP4 extrait dans : {extracted_mp4_path}")

        # Charge et lire la vidéo
        video = cv2.VideoCapture(extracted_mp4_path)

        if not video.isOpened():
            raise Exception("Impossible d'ouvrir la vidéo.")
            
        fps = video.get(cv2.CAP_PROP_FPS)
        frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        duration = frame_count / fps

        print(f"Vidéo prête à l'utilisation. Durée totale : {duration:.2f}s")

        # Lit une frame pour vérifier le contenu
        #ret, frame = video.read()
        #if ret:
            #print(f"Première frame lue avec succès. Taille : {frame.shape}")
        #else:
            #raise Exception("Impossible de lire la première frame de la vidéo.")

        #if not video.isOpened():
            #print("Error opening video stream or file")
            #exit()

        width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(video.get(cv2.CAP_PROP_FPS))

        print(f"Video info: {width}x{height}, {fps} fps")

        # Initialize the video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter('output.mp4', fourcc, fps, (width, height))

        # Boucle principale pour traiter chaque batch de frames
        frame_number= 0
        results =[]

        start_time = time.time()
        last_frame_time = start_time      
                
        #if not os.path.exists(yolov3_weights_path) or not os.path.exists(yolov3_cfg_path):
            #raise FileNotFoundError("Le fichier YOLO poids ou configuration manque.")

        #try:
            #with open(yolov3_cfg_path, "rb") as f:
                #config_data = f.read()
            #print(config_data[:50])  # Affiche les premières lignes du fichier pour vérifier son contenu
        #except Exception as e:
            #print(f"Erreur lors de la lecture du fichier de configuration YOLO : {str(e)}")

        batch_size = 60  # Nombre de frames par batch
        total_batches_per_segment = int(segment_duration * fps / batch_size)

        with tqdm(total=int(video.get(cv2.CAP_PROP_FRAME_COUNT))) as pbar:
            frame_number = 0
            frame_buffer = []
            total_frames_read = 0
            while True:
                try:
                    start_frame = frame_number
                    end_frame = start_frame + segment_duration * fps
                    
                    # Nettoyez le buffer avant d'ajouter de nouvelles frames
                    frame_buffer.clear()
                    
                    for _ in range(batch_size):
                        ret, frame = video.read()
                        if not ret:
                            break
                        total_frames_read += 1
                        reduced_frame = reduce_resolution(frame)
                        frame_buffer.append(reduced_frame)
                    print(f"Total frames read : {total_frames_read}")
                    
                    if not frame_buffer:
                        break
                    
                    if len(frame_buffer) == batch_size:
                        vehicle_boxes_list = process_single_frame(frame_buffer)
                    else:
                        print(f"Erreur : Le nombre de frames dans le buffer ({len(frame_buffer)}) n'est pas égal à {batch_size}")
                        continue
                        
                    
                    if not vehicle_boxes_list:
                        print(f"Aucun véhicule détecté dans la frame {frame_number}.")
                        continue
                    else:
                        print(f"{len(vehicle_boxes_list)} véhicules détectés dans la frame {frame_number}")
                        #show_results(results)
                        continue

                    # Création de l'image avec les véhicules détectés
                    detected_frame = frame_buffer[0].copy()
                    
                    for box in vehicle_boxes_list[0]:
                        x, y, w, h = box
                        color = tuple(np.random.randint(0, 256, 3).tolist())
                        cv2.rectangle(detected_frame, (x, y), (x+w, y+h), color, 2)

                    # Stocke les résultats
                    result_entry = {
                        "frame_number": frame_number,
                        "vehicle_boxes": vehicle_boxes_list[0],
                        "preprocessed_image": preprocess_image(frame_buffer[0]),
                        "detected_image": draw_bounding_boxes(frame_buffer[0], vehicle_boxes_list),
                        "elapsed_time": elapsed_time
                    }
                    results.append(result_entry)

                    pbar.update(batch_size)

                    # Incrémentation du frame_number après avoir traité toutes les frames dans le buffer
                    frame_number += batch_size

                    time.sleep(2)

                except Exception as e:
                    print(f"Erreur lors du traitement de la frame {frame_number} : {str(e)}")

                current_time = time.time()
                elapsed_time = current_time - last_frame_time
                last_frame_time = current_time
                
                if frame_number >= frame_count:
                    break

        print("Traitement des images et extraction des frames terminés.")
        
        # Ferme la vidéo
        video.release()
        cv2.destroyAllWindows()

    except zipfile.BadZipFile:
        print("Le fichier ZIP est corrompu ou invalide.")
    except Exception as e:
        print(f"Une erreur s'est produite : {str(e)}")

    finally:
        # On s'assure que tous les fichiers temporaires sont supprimés
        if 'temp_dir' in locals():
            temp_dir.cleanup()
        if os.path.exists(output_path):
            os.remove(output_path)
        if os.path.exists(extracted_mp4_path):
            os.remove(extracted_mp4_path)
        print("Tous les fichiers temporaires ont été supprimés.")

# %%
net = None
last_frame_time = time.time()
results = []

if __name__ == '__main__':
    main()
# Out:
# Téléchargement...
# Downloading...
# From (original): https://drive.google.com/uc?id=1TMEd1MA0Vy4PJycfBjx2a_EG0i9jpOzN
# From (redirected): https://drive.google.com/uc?id=1TMEd1MA0Vy4PJycfBjx2a_EG0i9jpOzN&confirm=t&uuid=85143172-717d-4dd7-9ab2-ae7ce1aefe19
# To: /var/folders/l6/g437mjmj6jd2n_lsl9mw8kym0000gn/T/tmpsi16tten/2-Jeu_Test_J2-10h30_P5 11.17.01.mp4.zip
# 100%|████████████████████████████████████████| 294M/294M [00:47<00:00, 6.24MB/s]
# Fichier téléchargé dans : /var/folders/l6/g437mjmj6jd2n_lsl9mw8kym0000gn/T/tmpsi16tten/2-Jeu_Test_J2-10h30_P5 11.17.01.mp4.zip
# Plusieurs fichiers MP4 trouvés : 2-Jeu_Test_J2-10h30_P5 11.17.01.mp4, __MACOSX/._2-Jeu_Test_J2-10h30_P5 11.17.01.mp4
# Fichier MP4 extrait dans : /var/folders/l6/g437mjmj6jd2n_lsl9mw8kym0000gn/T/tmpsi16tten/2-Jeu_Test_J2-10h30_P5 11.17.01.mp4
# Vidéo prête à l'utilisation. Durée totale : 116.97s
# Video info: 1920x1080, 30 fps
#   0%|                                                  | 0/3509 [00:00<?, ?it/s]
# Total frames read : 60
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 120
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 180
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 240
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 300
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 360
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 420
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 480
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 540
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 600
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 660
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 720
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 780
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 840
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 900
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 960
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1020
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1080
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1140
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1200
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1260
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1320
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1380
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1440
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1500
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1560
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1620
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1680
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1740
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1800
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1860
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1920
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 1980
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2040
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2100
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2160
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2220
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2280
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2340
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2400
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2460
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2520
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2580
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2640
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2700
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2760
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2820
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2880
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 2940
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3000
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3060
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3120
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3180
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3240
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3300
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3360
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3420
# Aucun véhicule détecté dans la frame 0.
# Total frames read : 3480
# Aucun véhicule détecté dans la frame 0.
#   0%|                                                  | 0/3509 [00:50<?, ?it/s]
# Total frames read : 3509
# Erreur : Le nombre de frames dans le buffer (29) n'est pas égal à 60
# Total frames read : 3509
# Traitement des images et extraction des frames terminés.
# Tous les fichiers temporaires ont été supprimés.

# %%
# Après la boucle principale, ajoutez :
display_results(results)

# %%
with open(yolov3_cfg_path, "r") as f:
    config_content = f.read()
print(config_content)
# Out:
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# ######################
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
#
#
# [yolo]
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 61
#
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
#
#
# [yolo]
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 36
#
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=255
# activation=linear
#
#
# [yolo]
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=80
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1

# %%
import cv2

def get_video_fps(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    cap.release()
    return fps

video_path = "chemin_vers_votre_video.mp4"
fps = get_video_fps(video_path)
print(f"Nombre de frames par seconde : {fps}")
